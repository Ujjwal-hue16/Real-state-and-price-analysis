# %% [markdown]
# # **Needed Libraries**

# %%
import numpy as np 
import pandas as pd 
import plotly.express as px 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # **Reading Data**

# %%
df=pd.read_csv('Housing.csv')

# %% [markdown]
# # **Data Exploration**

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7229300521  20141013T000000  231300.0         2       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580306e+09  5.400886e+05      3.370795      2.114757   2079.899736
# std    2.876570e+09  3.671268e+05      0.930105      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Length: 21613, dtype: bool

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.nunique()
# Out:
# id               21436
# date               372
# price             4029
# bedrooms            13
# bathrooms           30
# sqft_living       1038
# sqft_lot          9782
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               12
# sqft_above         946
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# dtype: int64

# %% [markdown]
# # **Data Cleaning**

# %%
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# # **Analysis and Visualization**

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7229300521 2014-10-13  231300.0         2       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.id.value_counts().count()
# Out:
# np.int64(21436)

# %%
rooms_lot= df.groupby('bedrooms')['sqft_lot'].count().reset_index()
rooms_lot
# Out:
#     bedrooms  sqft_lot
# 0          0        13
# 1          1       199
# 2          2      2761
# 3          3      9823
# 4          4      6882
# 5          5      1601
# 6          6       272
# 7          7        38
# 8          8        13
# 9          9         6
# 10        10         3
# 11        11         1
# 12        33         1

# %%
px.scatter(rooms_lot ,x='sqft_lot',y='bedrooms',title='Relationship between Sqft Lot and Bedrooms')

# %%
bedroom_price = df.groupby('bedrooms')['price'].mean().reset_index()
bedroom_price
# Out:
#     bedrooms         price
# 0          0  4.095038e+05
# 1          1  3.176429e+05
# 2          2  4.013111e+05
# 3          3  4.662570e+05
# 4          4  6.354195e+05
# 5          5  7.865998e+05
# 6          6  8.255206e+05
# 7          7  9.511847e+05
# 8          8  1.105077e+06
# 9          9  8.939998e+05
# 10        10  8.193333e+05
# 11        11  5.200000e+05
# 12        33  6.400000e+05

# %%
px.line(bedroom_price ,x='bedrooms',y='price',title='Price trends to no of Bedrooms')

# %%
px.scatter(df,'price')

# %%
date_price=df.groupby('date')['price'].count().reset_index()
date_price
# Out:
#           date  price
# 0   2014-05-02     67
# 1   2014-05-03      4
# 2   2014-05-04      5
# 3   2014-05-05     84
# 4   2014-05-06     83
# ..         ...    ...
# 367 2015-05-13     31
# 368 2015-05-14     11
# 369 2015-05-15      1
# 370 2015-05-24      1
# 371 2015-05-27      1
#
# [372 rows x 2 columns]

# %%
px.line(date_price,x='date',y='price',title ='Data vs Price')

# %%
bathroom_bedroom = df.groupby('bathrooms')['bedrooms'].mean().reset_index().astype(int)
bathroom_bedroom
# Out:
#     bathrooms  bedrooms
# 0           0         0
# 1           0         2
# 2           0         1
# 3           1         2
# 4           1         2
# 5           1         3
# 6           1         3
# 7           2         3
# 8           2         3
# 9           2         3
# 10          2         3
# 11          3         4
# 12          3         3
# 13          3         4
# 14          3         4
# 15          4         4
# 16          4         4
# 17          4         4
# 18          4         5
# 19          5         5
# 20          5         5
# 21          5         4
# 22          5         5
# 23          6         5
# 24          6         5
# 25          6         5
# 26          6         6
# 27          7         9
# 28          7         6
# 29          8         6

# %%
px.bar( bathroom_bedroom,x='bedrooms',y='bathrooms',title='Bedrooms vs Bathrooms')

# %%
bathroom_price = df.groupby('bathrooms')['price'].mean().reset_index().astype(int)
bathroom_price
# Out:
#     bathrooms    price
# 0           0   448160
# 1           0   237375
# 2           0   294520
# 3           1   347043
# 4           1   621216
# 5           1   409322
# 6           1   454896
# 7           2   457889
# 8           2   533676
# 9           2   553596
# 10          2   660230
# 11          3   708415
# 12          3   970339
# 13          3   931933
# 14          3  1197216
# 15          4  1267709
# 16          4  1525774
# 17          4  1333620
# 18          4  2021303
# 19          5  1673491
# 20          5  1817176
# 21          5  2522300
# 22          5  2492500
# 23          6  2946833
# 24          6  3094000
# 25          6  1709445
# 26          6  2734000
# 27          7   450000
# 28          7  6885000
# 29          8  4990000

# %%
px.bar( bathroom_price,x='bathrooms',y='price',title='Price vs Bathrooms')

# %%
floors_price= df.groupby('floors')['price'].mean().reset_index().astype(int)
floors_price
# Out:
#    floors    price
# 0       1   442181
# 1       1   558980
# 2       2   648891
# 3       2  1060346
# 4       3   582526
# 5       3   933312

# %%
px.line( floors_price,x='floors',y='price',title='Price trends to no of Floors')

# %%
waterfront_view = pd.crosstab(df['waterfront'], df['view'])
waterfront_view
# Out:
# view            0    1    2    3    4
# waterfront
# 0           19489  331  955  491  184
# 1               0    1    8   19  135

# %%
px.imshow(waterfront_view,labels=dict(x="View", y="Waterfront", color="Count"),
                x=waterfront_view.columns,
                y=waterfront_view.index,
                color_continuous_scale='viridis')

# %%
grade_condition =pd.crosstab(df['grade'], df['condition'])
grade_condition
# Out:
# condition   1   2     3     4    5
# grade
# 1           1   0     0     0    0
# 3           0   1     1     0    1
# 4           1   5    13    10    0
# 5           9  15   100    84   34
# 6          11  59  1035   685  248
# 7           6  75  5234  2833  833
# 8           2  13  4269  1394  390
# 9           0   2  2041   446  126
# 10          0   2   921   156   55
# 11          0   0   332    56   11
# 12          0   0    74    13    3
# 13          0   0    11     2    0

# %%
px.imshow(grade_condition,
                 labels=dict(x="Grade", y="Condition", color="Count"),
                 x=grade_condition.columns,
                 y=grade_condition.index,
                 color_continuous_scale='viridis',
                 title='Cross-tabulation between Grade and Condition')

# %%
zipcode_price = df.groupby('zipcode')['price'].median().reset_index()
zipcode_price
# Out:
#     zipcode      price
# 0     98001   260000.0
# 1     98002   235000.0
# 2     98003   267475.0
# 3     98004  1150000.0
# 4     98005   765475.0
# ..      ...        ...
# 65    98177   554000.0
# 66    98178   278277.0
# 67    98188   264000.0
# 68    98198   265000.0
# 69    98199   689800.0
#
# [70 rows x 2 columns]

# %%
px.bar(zipcode_price, x='zipcode', y='price', title='House Price by Zipcode')

# %%
yr_built_price = df.groupby('yr_built')['price'].median().reset_index()
yr_built_price
# Out:
#      yr_built     price
# 0        1900  549000.0
# 1        1901  550000.0
# 2        1902  624000.0
# 3        1903  461000.0
# 4        1904  478000.0
# ..        ...       ...
# 111      2011  440000.0
# 112      2012  448475.0
# 113      2013  565000.0
# 114      2014  599000.0
# 115      2015  629500.0
#
# [116 rows x 2 columns]

# %%
px.line(yr_built_price, x=yr_built_price.index, y='price', title='House Price by Year Built')

# %%
sqft_living_price = df.groupby('sqft_living')['price'].median().reset_index()

# %%
px.scatter(sqft_living_price, x='sqft_living', y='price', 
                                   title='Relationship between Sqft Living and Price')

# %%
sqft_lot_price = df.groupby('sqft_lot')['price'].median().reset_index()

# %%
px.scatter(sqft_lot_price, x='sqft_lot', y='price', 
                                   title='Relationship between Sqft Lot and Price')

# %%
floors_price = df.groupby('floors')['price'].median().reset_index()

# %%
px.bar(floors_price, x='floors', y='price',title='Relationship between Floors and Price')

# %%
view_price = df.groupby('view')['price'].median().reset_index()

# %%
px.scatter(view_price, x='view', y='price',title='Relationship between View and Price')

# %%
condition_price = df.groupby('condition')['price'].median().reset_index()

# %%
px.bar(condition_price, x='condition', y='price',title='Relationship between Condition and Price')

# %%
grade_price = df.groupby('grade')['price'].median().reset_index()

# %%
px.bar(grade_price, x='grade', y='price', title='Relationship between Grade and Price')

# %%
waterfront_price = df.groupby('waterfront')['price'].median().reset_index()

# %%
px.bar(waterfront_price, x='waterfront', y='price',title='Relationship between Waterfront and Price')
